# %%
import pandas as pd
food_nutrient = pd.read_csv('food_nutrient.csv')

# %%
food_nutrient_incomplete = food_nutrient[food_nutrient["amount"].isna()]
food_nutrient_incomplete.head()
# Out:
#     fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  median  \
# 0  1106032         1257     NaN          NaN           71.0  NaN  NaN     NaN
# 1  1107191         1257     NaN          NaN           70.0  NaN  NaN     NaN
# 2  1107295         1257     NaN          NaN           70.0  NaN  NaN     NaN
# 3  1107475         1257     NaN          NaN           70.0  NaN  NaN     NaN
#
#    loq  footnote  min_year_acquired                      name unit_name
# 0  NaN       NaN                NaN  Fatty acids, total trans         G
# 1  NaN       NaN                NaN  Fatty acids, total trans         G
# 2  NaN       NaN                NaN  Fatty acids, total trans         G
# 3  NaN       NaN                NaN  Fatty acids, total trans         G

# %%
food_nutrient = food_nutrient.dropna(subset="amount")
#food_nutrient.dropna(subset="amount", inplace=True)

# %%
food_nutrient_complete = food_nutrient[food_nutrient["amount"].notna()]
food_nutrient_complete.head()
# Out:
#     fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  median  \
# 4  1107528         1257     0.0          NaN           70.0  NaN  NaN     NaN
# 5  1108007         1257     0.0          NaN           70.0  NaN  NaN     NaN
# 6  1108158         1257     0.0          NaN           70.0  NaN  NaN     NaN
# 7  1108349         1257     0.0          NaN           70.0  NaN  NaN     NaN
# 8  1108803         1257     0.0          NaN           70.0  NaN  NaN     NaN
#
#    loq  footnote  min_year_acquired                      name unit_name
# 4  NaN       NaN                NaN  Fatty acids, total trans         G
# 5  NaN       NaN                NaN  Fatty acids, total trans         G
# 6  NaN       NaN                NaN  Fatty acids, total trans         G
# 7  NaN       NaN                NaN  Fatty acids, total trans         G
# 8  NaN       NaN                NaN  Fatty acids, total trans         G

# %%
food_sample_100 = pd.read_csv("food_sample_100.csv")
food_other = pd.read_csv("food_other.csv")
food = pd.concat([food_sample_100, food_other], ignore_index=True)

# %%
food_sample_100.head()
# Out:
#     fdc_id        data_type    description  food_category_id publication_date
# 0  2644829  sub_sample_food   lentils, dry              16.0       2023-10-19
# 1  2347263  sub_sample_food    heavy cream               1.0       2022-10-28
# 2  2261954  sub_sample_food  Flour, potato              11.0       2022-04-28
# 3   321470  sub_sample_food  Salt, Iodized               2.0       2019-04-01
# 4   322951  sub_sample_food  Hot dogs beef               7.0       2019-04-01

# %%
food_other.head()
# Out:
#     fdc_id     data_type                                        description  \
# 0  1106032  branded_food  Chicken, FC Beer Battered Boneless Wing Fritte...
# 1  1107191  branded_food                           MARINARA SAUCE, MARINARA
# 2  1107295  branded_food           ORIGINAL ROUNDS TORTILLA CHIPS, ORIGINAL
# 3  1107475  branded_food       NACHO QUESO SUPREME DIP, NACHO QUESO SUPREME
# 4  1107528  branded_food                      CLASSIC JUMBO FRANKS, CLASSIC
#
#    food_category_id publication_date
# 0               NaN       2020-11-13
# 1               NaN       2020-11-13
# 2               NaN       2020-11-13
# 3               NaN       2020-11-13
# 4               NaN       2020-11-13

# %%
pd.concat([food_sample_100, food_other])
# Out:
#        fdc_id        data_type  \
# 0     2644829  sub_sample_food
# 1     2347263  sub_sample_food
# 2     2261954  sub_sample_food
# 3      321470  sub_sample_food
# 4      322951  sub_sample_food
# ...       ...              ...
# 9895  2661515     branded_food
# 9896  2661730     branded_food
# 9897  2661782     branded_food
# 9898  2662107     branded_food
# 9899  2662182     branded_food
#
#                                             description  food_category_id  \
# 0                                          lentils, dry              16.0
# 1                                           heavy cream               1.0
# 2                                         Flour, potato              11.0
# 3                                         Salt, Iodized               2.0
# 4                                         Hot dogs beef               7.0
# ...                                                 ...               ...
# 9895  CHAI LATTE SUGAR FREE BLACK TEA CONCENTRATE, C...               NaN
# 9896   APPLE BANANA ORGANIC FRUIT POUCHES, APPLE BANANA               NaN
# 9897                     SPINACH ORGANIC PUREE, SPINACH               NaN
# 9898  LIGHT MOZZARELLA LOW-MOISTURE PART-SKIM STRING...               NaN
# 9899  ITALIAN-STYLE DICED TOMATOES WITH BASIL, GARLI...               NaN
#
#      publication_date
# 0          2023-10-19
# 1          2022-10-28
# 2          2022-04-28
# 3          2019-04-01
# 4          2019-04-01
# ...               ...
# 9895       2023-10-26
# 9896       2023-10-26
# 9897       2023-10-26
# 9898       2023-10-26
# 9899       2023-10-26
#
# [10000 rows x 5 columns]

# %%
print(food.shape)
print(food_nutrient.shape)
# Out:
# (10000, 5)
# (135332, 13)

# %%
food_merged = pd.merge(food, food_nutrient, on="fdc_id", how="inner")
food_merged.shape
food_merged.head()
# Out:
#     fdc_id        data_type    description  food_category_id publication_date  \
# 0  2644829  sub_sample_food   lentils, dry              16.0       2023-10-19
# 1  2347263  sub_sample_food    heavy cream               1.0       2022-10-28
# 2  2261954  sub_sample_food  Flour, potato              11.0       2022-04-28
# 3   321470  sub_sample_food  Salt, Iodized               2.0       2019-04-01
# 4   321470  sub_sample_food  Salt, Iodized               2.0       2019-04-01
#
#    nutrient_id  amount  data_points  derivation_id  min  max  median  loq  \
# 0         1101    1.58          1.0            1.0  NaN  NaN     NaN  NaN
# 1         1258   20.00          1.0            1.0  NaN  NaN     NaN  NaN
# 2         1102   21.80          1.0            1.0  NaN  NaN     NaN  NaN
# 3         1051    0.69          1.0            1.0  NaN  NaN     NaN  NaN
# 4         1007   98.40          1.0            1.0  NaN  NaN     NaN  NaN
#
#    footnote  min_year_acquired                          name unit_name
# 0       NaN                NaN                 Manganese, Mn        MG
# 1       NaN                NaN  Fatty acids, total saturated         G
# 2       NaN                NaN                Molybdenum, Mo        UG
# 3       NaN                NaN                         Water         G
# 4       NaN                NaN                           Ash         G
